# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # This notebook contains the summary of "Data Science Tools and Ecosystem" course

# %% [markdown]
# # **Objectives**
# * List popular languages of Data Science
# * List popular libraries of Data Science
# * List open-source development environments of Data Science

# %% [markdown]
# # Here are some of the popular languages used by Data Science specialists:
# 1. R
# 2. Python
# 3. SQL
# 4. Julia
# 5. Java

# %% [markdown]
# # Here are some of the popular libraries used by Data Science specialists:
# 1. pandas
# 2. scikit-learn
# 3. Matplotlib
# 4. NumPy
# 5. PyTorch

# %% [markdown]
# # Open-source development environment tools used in Data Science
#
# | Data Science Tools |
# |---|
# | RStudio |
# | Jupyter Lab |
# | Spyder |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %%
# Use of multiplication and addition. The result is 17
(3*4)+5
# Out:
# 17

# %%
# This expression converts minutes into hours by dividing by 60:
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Liubov Slasten
